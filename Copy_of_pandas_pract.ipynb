# %%
import pandas as pd

# %%
from google.colab import files
uploaded_file = files.upload()
# Out:
#      <input type="file" id="files-24f1d187-5743-4e7f-8c10-71a72a9edad2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24f1d187-5743-4e7f-8c10-71a72a9edad2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving NetflixOriginals.csv to NetflixOriginals.csv

# %%
import io
df1 = pd.read_csv(io.BytesIO(uploaded_file["NetflixOriginals.csv"]),encoding = "ISO-8859-1")

# %%
#reading shape of dataset
df1.shape
# Out:
# (584, 6)

# %%
#reading first 10 heads
df1.head(10)
# Out:
#                              Title                    Genre  \
# 0                  Enter the Anime              Documentary
# 1                      Dark Forces                 Thriller
# 2                          The App    Science fiction/Drama
# 3                   The Open House          Horror thriller
# 4                      Kaali Khuhi                  Mystery
# 5                            Drive                   Action
# 6                Leyla Everlasting                   Comedy
# 7  The Last Days of American Crime      Heist film/Thriller
# 8                          Paradox  Musical/Western/Fantasy
# 9               Sardar Ka Grandson                   Comedy
#
#             Premiere  Runtime  IMDB Score          Language
# 0     August 5, 2019       58         2.5  English/Japanese
# 1    August 21, 2020       81         2.6           Spanish
# 2  December 26, 2019       79         2.6           Italian
# 3   January 19, 2018       94         3.2           English
# ...

# %%
#printting column names
df1.columns
# Out:
# Index(['Title', 'Genre', 'Premiere', 'Runtime', 'IMDB Score', 'Language'], dtype='object')

# %%
#description of database......stattistical summary
df1.describe()
# Out:
#           Runtime  IMDB Score
# count  584.000000  584.000000
# mean    93.577055    6.271747
# std     27.761683    0.979256
# min      4.000000    2.500000
# 25%     86.000000    5.700000
# 50%     97.000000    6.350000
# 75%    108.000000    7.000000
# max    209.000000    9.000000

# %%
#printing information
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 584 entries, 0 to 583
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       584 non-null    object
#  1   Genre       584 non-null    object
#  2   Premiere    584 non-null    object
#  3   Runtime     584 non-null    int64
#  4   IMDB Score  584 non-null    float64
#  5   Language    584 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 27.5+ KB

# %%
#checking for null values
df1["Title"].isnull().sum()
# Out:
# 0

# %%
#checking for null values
df1["Title"].notnull().sum()
# Out:
# 584

# %%
#printing count of top scored IMDB movies
df1[df1["IMDB Score"] > 8].count()
# Out:
# Title         16
# Genre         16
# Premiere      16
# Runtime       16
# IMDB Score    16
# Language      16
# dtype: int64

# %%
#printing lowest rated movies

t1 = df1[df1["IMDB Score"] < 5]

# %%
t1
# Out:
#                                                Title                    Genre  \
# 0                                    Enter the Anime              Documentary
# 1                                        Dark Forces                 Thriller
# 2                                            The App    Science fiction/Drama
# 3                                     The Open House          Horror thriller
# 4                                        Kaali Khuhi                  Mystery
# 5                                              Drive                   Action
# 6                                  Leyla Everlasting                   Comedy
# 7                    The Last Days of American Crime      Heist film/Thriller
# 8                                            Paradox  Musical/Western/Fantasy
# 9                                 Sardar Ka Grandson                   Comedy
# 10                              Searching for Sheela              Documentary
# ...

# %%
t1.count()
# Out:
# Title         54
# Genre         54
# Premiere      54
# Runtime       54
# IMDB Score    54
# Language      54
# dtype: int64

# %%
df1.duplicated
# Out:
# <bound method DataFrame.duplicated of                                            Title                  Genre  \
# 0                                Enter the Anime            Documentary
# 1                                    Dark Forces               Thriller
# 2                                        The App  Science fiction/Drama
# 3                                 The Open House        Horror thriller
# 4                                    Kaali Khuhi                Mystery
# ..                                           ...                    ...
# 579        Taylor Swift: Reputation Stadium Tour           Concert Film
# 580  Winter on Fire: Ukraine's Fight for Freedom            Documentary
# 581                      Springsteen on Broadway           One-man show
# 582    Emicida: AmarElo - It's All For Yesterday            Documentary
# 583     David Attenborough: A Life on Our Planet            Documentary
#
# ...

# %%
#finding hindi movies in db 
t2 = df1[df1["Language"]=="Hindi"]

# %%
t2.count()
# Out:
# Title         33
# Genre         33
# Premiere      33
# Runtime       33
# IMDB Score    33
# Language      33
# dtype: int64

# %%
t2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 4 to 551
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       33 non-null     object
#  1   Genre       33 non-null     object
#  2   Premiere    33 non-null     object
#  3   Runtime     33 non-null     int64
#  4   IMDB Score  33 non-null     float64
#  5   Language    33 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.8+ KB

# %%
t3 = df1["Language"].unique()

# %%
t3
# Out:
# array(['English/Japanese', 'Spanish', 'Italian', 'English', 'Hindi',
#        'Turkish', 'Korean', 'Indonesian', 'Malay', 'Dutch', 'French',
#        'English/Spanish', 'Portuguese', 'Filipino', 'German', 'Polish',
#        'Norwegian', 'Marathi', 'Thai', 'Swedish', 'Japanese',
#        'Spanish/Basque', 'Spanish/Catalan', 'English/Swedish',
#        'English/Taiwanese/Mandarin', 'Thia/English', 'English/Mandarin',
#        'Georgian', 'Bengali', 'Khmer/English/French', 'English/Hindi',
#        'Tamil', 'Spanish/English', 'English/Korean', 'English/Arabic',
#        'English/Russian', 'English/Akan', 'English/Ukranian/Russian'],
#       dtype=object)

# %%
df1[df1["Language"]=="English"].count()
# Out:
# Title         401
# Genre         401
# Premiere      401
# Runtime       401
# IMDB Score    401
# Language      401
# dtype: int64

# %%
df1[df1["Language"]=="English"].nunique()
# Out:
# Title         401
# Genre         101
# Premiere      307
# Runtime       114
# IMDB Score     49
# Language        1
# dtype: int64

# %%
for i in t3:
  print("language is : ",i)
  print(df1[df1["Language"]==i].count())
# Out:
# language is :  English/Japanese
# Title         2
# Genre         2
# Premiere      2
# Runtime       2
# IMDB Score    2
# Language      2
# dtype: int64
# language is :  Spanish
# Title         31
# Genre         31
# Premiere      31
# Runtime       31
# IMDB Score    31
# Language      31
# dtype: int64
# language is :  Italian
# Title         14
# Genre         14
# Premiere      14
# Runtime       14
# IMDB Score    14
# Language      14
# dtype: int64
# language is :  English
# Title         401
# Genre         401
# Premiere      401
# Runtime       401
# IMDB Score    401
# Language      401
# dtype: int64
# language is :  Hindi
# Title         33
# Genre         33
# Premiere      33
# Runtime       33
# IMDB Score    33
# Language      33
# dtype: int64
# language is :  Turkish
# Title         5
# Genre         5
# Premiere      5
# Runtime       5
# IMDB Score    5
# Language      5
# dtype: int64
# language is :  Korean
# Title         6
# Genre         6
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-66801aa38741> in <module>()
#       1 # sum = 0
# ----> 2 for i in t3:
#       3   if (i=="English") and ("English/ " in i):
#       4     print("language is : ",i)
#       5     print(df1[df1["Language"]==i].count())
#
# NameError: name 't3' is not defined
